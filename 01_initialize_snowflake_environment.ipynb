# %%
from snowflake.snowpark import Session
import time

# %%
def get_snowflake_session():
    """Create a Snowflake session using ACCOUNTADMIN credentials."""
    try:
        from typing import Dict, Union

        connection_parameters: Dict[str, Union[str, int]] = {
            "account": "FVQCWWK-IJB71419",
            "user": "LALIT",
            "password": "Klalitkumar@2025",
            "authenticator": "snowflake",
            "role": "ACCOUNTADMIN",
            "warehouse": "COMPUTE_WH",
            "database": "SNOWFLAKE",
            "schema": "PUBLIC"
        }
        session = Session.builder.configs(connection_parameters).create()
        print("Snowflake session established successfully.")
        return session
    except Exception as e:
        print(f"Error establishing Snowflake session: {str(e)}")
        raise

# %%
def check_and_create_role(session):
    """Check if role exists and create if not present."""
    start_time = time.time()
    role_name = "RECOMMENDATION_SYSTEM_ROLE"
    try:
        # Check if role exists
        roles_df = session.sql(f"""
            SELECT NAME FROM SNOWFLAKE.ACCOUNT_USAGE.ROLES
            WHERE NAME = '{role_name}' AND DELETED IS NULL
        """).to_pandas()
        if not roles_df.empty:
            print(f"Role {role_name} already exists.")
        else:
            session.sql(f"""
                CREATE ROLE IF NOT EXISTS {role_name}
                COMMENT = 'Role for Dealer Product Recommendation System'
            """).collect()
            print(f"Created role: {role_name}")

        # Grant role to ACCOUNTADMIN and user
        session.sql(f"""
            GRANT ROLE {role_name} TO ROLE ACCOUNTADMIN
        """).collect()
        print(f"Granted {role_name} to ACCOUNTADMIN")
        session.sql(f"""
            GRANT ROLE {role_name} TO USER LALIT
        """).collect()
        print(f"Granted {role_name} to user LALIT")

        print(f"check_and_create_role completed in {time.time() - start_time:.2f} seconds")
        return role_name
    except Exception as e:
        print(f"Error in check_and_create_role: {str(e)}")
        raise

# %%
def check_and_create_warehouse(session):
    """Check if warehouse exists and create if not present."""
    start_time = time.time()
    warehouse_name = "RECOMMENDATION_SYSTEM_WH"
    role_name = "RECOMMENDATION_SYSTEM_ROLE"
    try:
        # Check if warehouse exists
        warehouses_df = session.sql(f"""
            SELECT WAREHOUSE_NAME FROM SNOWFLAKE.ACCOUNT_USAGE.WAREHOUSES
            WHERE WAREHOUSE_NAME = '{warehouse_name}' AND DELETED IS NULL
        """).to_pandas()
        if not warehouses_df.empty:
            print(f"Warehouse {warehouse_name} already exists.")
        else:
            session.sql(f"""
                CREATE WAREHOUSE IF NOT EXISTS {warehouse_name}
                WITH
                    WAREHOUSE_SIZE = 'XSMALL'
                    AUTO_SUSPEND = 300
                    AUTO_RESUME = TRUE
                    COMMENT = 'Warehouse for Dealer Product Recommendation System'
            """).collect()
            print(f"Created warehouse: {warehouse_name}")

        # Grant warehouse privileges
        session.sql(f"""
            GRANT ALL ON WAREHOUSE {warehouse_name} TO ROLE {role_name}
        """).collect()
        print(f"Granted ALL privileges on warehouse {warehouse_name} to {role_name}")

        print(f"check_and_create_warehouse completed in {time.time() - start_time:.2f} seconds")
        return warehouse_name
    except Exception as e:
        print(f"Error in check_and_create_warehouse: {str(e)}")
        raise

# %%
def check_and_create_database(session):
    """Check if database exists and create if not present."""
    start_time = time.time()
    database_name = "RECOMMENDATION_SYSTEM_DB"
    role_name = "RECOMMENDATION_SYSTEM_ROLE"
    try:
        # Check if database exists
        databases_df = session.sql(f"""
            SELECT DATABASE_NAME FROM SNOWFLAKE.ACCOUNT_USAGE.DATABASES
            WHERE DATABASE_NAME = '{database_name}' AND DELETED IS NULL
        """).to_pandas()
        if not databases_df.empty:
            print(f"Database {database_name} already exists.")
        else:
            session.sql(f"""
                CREATE DATABASE IF NOT EXISTS {database_name}
                COMMENT = 'Database for Dealer Product Recommendation System'
            """).collect()
            print(f"Created database: {database_name}")

        # Grant database privileges
        session.sql(f"""
            GRANT ALL ON DATABASE {database_name} TO ROLE {role_name}
        """).collect()
        print(f"Granted ALL privileges on database {database_name} to {role_name}")

        print(f"check_and_create_database completed in {time.time() - start_time:.2f} seconds")
        return database_name
    except Exception as e:
        print(f"Error in check_and_create_database: {str(e)}")
        raise

# %%
def check_and_create_schemas(session, database_name):
    """Check if schemas exist and create if not present."""
    start_time = time.time()
    schemas = ["ODS", "STG", "DWH"]
    role_name = "RECOMMENDATION_SYSTEM_ROLE"
    try:
        # Check existing schemas
        schemas_df = session.sql(f"""
            SELECT SCHEMA_NAME FROM {database_name}.INFORMATION_SCHEMA.SCHEMATA
            WHERE SCHEMA_NAME IN ('ODS', 'STG', 'DWH')
        """).to_pandas()
        existing_schemas = schemas_df['SCHEMA_NAME'].tolist()
        print(f"Existing schemas in {database_name}: {existing_schemas}")

        # Create missing schemas
        for schema in schemas:
            if schema not in existing_schemas:
                session.sql(f"""
                    CREATE SCHEMA IF NOT EXISTS {database_name}.{schema}
                    COMMENT = '{schema} schema for Dealer Product Recommendation System'
                """).collect()
                print(f"Created schema: {database_name}.{schema}")
            else:
                print(f"Schema {database_name}.{schema} already exists.")

            # Grant schema privileges
            session.sql(f"""
                GRANT ALL ON SCHEMA {database_name}.{schema} TO ROLE {role_name}
            """).collect()
            print(f"Granted ALL privileges on schema {database_name}.{schema} to {role_name}")

        print(f"check_and_create_schemas completed in {time.time() - start_time:.2f} seconds")
        return schemas
    except Exception as e:
        print(f"Error in check_and_create_schemas: {str(e)}")
        raise

# %%
def check_and_create_tables(session, database_name):
    """Check if tables exist and create if not present."""
    start_time = time.time()
    role_name = "RECOMMENDATION_SYSTEM_ROLE"
    tables = ["DEALERS", "PRODUCTS", "SALES", "DP_MAPPING", "EC_CLUB"]
    try:
        # Check existing tables
        tables_df = session.sql(f"""
            SELECT TABLE_NAME 
            FROM {database_name}.INFORMATION_SCHEMA.TABLES 
            WHERE TABLE_SCHEMA = 'ODS' 
            AND TABLE_NAME IN ('DEALERS', 'PRODUCTS', 'SALES', 'DP_MAPPING', 'EC_CLUB')
        """).to_pandas()
        existing_tables = tables_df['TABLE_NAME'].tolist()
        print(f"Existing tables in {database_name}.ODS: {existing_tables}")

        # Create missing tables
        if 'DEALERS' not in existing_tables:
            session.sql(f"""
                CREATE TABLE IF NOT EXISTS {database_name}.ODS.DEALERS (
                    DEALER_NO VARCHAR(50) PRIMARY KEY,
                    DEALER_NAME VARCHAR(100),
                    REGION VARCHAR(50),
                    ADDRESS VARCHAR(200),
                    ANNUAL_REVENUE DECIMAL(18,2),
                    DEALER_TYPE VARCHAR(20),
                    EC_CLUB INTEGER,
                    TOTAL_SALES DECIMAL(18,2) DEFAULT 0,
                    TOTAL_INVOICES INTEGER DEFAULT 0,
                    AVERAGE_BILL_VALUE DECIMAL(18,2) DEFAULT 0,
                    AVERAGE_SKUS_PER_INVOICE DECIMAL(18,2) DEFAULT 0
                )
                COMMENT = 'Table storing dealer information'
            """).collect()
            print(f"Created table: {database_name}.ODS.DEALERS")
        else:
            print(f"Table {database_name}.ODS.DEALERS already exists.")

        if 'PRODUCTS' not in existing_tables:
            session.sql(f"""
                CREATE TABLE IF NOT EXISTS {database_name}.ODS.PRODUCTS (
                    SKU VARCHAR(50) PRIMARY KEY,
                    PRODUCT_NAME VARCHAR(100),
                    PROD_CATEGORY VARCHAR(50),
                    PROD_RANGE VARCHAR(50),
                    PROD_SUBCATEGORY VARCHAR(50),
                    IS_TRADING INTEGER,
                    IS_FINISHED INTEGER
                )
                COMMENT = 'Table storing product information'
            """).collect()
            print(f"Created table: {database_name}.ODS.PRODUCTS")
        else:
            print(f"Table {database_name}.ODS.PRODUCTS already exists.")

        if 'SALES' not in existing_tables:
            session.sql(f"""
                CREATE TABLE IF NOT EXISTS {database_name}.ODS.SALES (
                    DEALER_NO VARCHAR(50),
                    SKU VARCHAR(50),
                    DATE DATE,
                    QUANTITY INTEGER,
                    AMOUNT DECIMAL(18,2),
                    PRIMARY KEY (DEALER_NO, SKU, DATE)
                )
                COMMENT = 'Table storing sales transactions'
            """).collect()
            print(f"Created table: {database_name}.ODS.SALES")
        else:
            print(f"Table {database_name}.ODS.SALES already exists.")

        if 'DP_MAPPING' not in existing_tables:
            session.sql(f"""
                CREATE TABLE IF NOT EXISTS {database_name}.ODS.DP_MAPPING (
                    DN_NUMBER VARCHAR(50) PRIMARY KEY,
                    VERTICAL VARCHAR(50)
                )
                COMMENT = 'Table storing dealer-vertical mappings'
            """).collect()
            print(f"Created table: {database_name}.ODS.DP_MAPPING")
        else:
            print(f"Table {database_name}.ODS.DP_MAPPING already exists.")

        if 'EC_CLUB' not in existing_tables:
            session.sql(f"""
                CREATE TABLE IF NOT EXISTS {database_name}.ODS.EC_CLUB (
                    DEALER_NO VARCHAR(50) PRIMARY KEY,
                    EC_CLUB INTEGER
                )
                COMMENT = 'Table storing elite club membership'
            """).collect()
            print(f"Created table: {database_name}.ODS.EC_CLUB")
        else:
            print(f"Table {database_name}.ODS.EC_CLUB already exists.")

        # Grant table privileges
        for table in tables:
            session.sql(f"""
                GRANT ALL ON TABLE {database_name}.ODS.{table} TO ROLE {role_name}
            """).collect()
            print(f"Granted ALL privileges on table {database_name}.ODS.{table} to {role_name}")

        print(f"check_and_create_tables completed in {time.time() - start_time:.2f} seconds")
    except Exception as e:
        print(f"Error in check_and_create_tables: {str(e)}")
        raise

# %%
def grant_usage_privileges(session, warehouse_name, database_name):
    """Grant usage privileges to the role for warehouse and database."""
    start_time = time.time()
    role_name = "RECOMMENDATION_SYSTEM_ROLE"
    try:
        # Grant warehouse usage
        session.sql(f"""
            GRANT USAGE ON WAREHOUSE {warehouse_name} TO ROLE {role_name}
        """).collect()
        print(f"Granted USAGE on warehouse {warehouse_name} to {role_name}")

        # Grant database usage
        session.sql(f"""
            GRANT USAGE ON DATABASE {database_name} TO ROLE {role_name}
        """).collect()
        print(f"Granted USAGE on database {database_name} to {role_name}")

        print(f"grant_usage_privileges completed in {time.time() - start_time:.2f} seconds")
    except Exception as e:
        print(f"Error in grant_usage_privileges: {str(e)}")
        raise

# %%
def main():
    """Main function to set up the Snowflake environment with existence checks."""
    start_time = time.time()
    try:
        print("Starting Snowflake environment setup...")

        # Establish Snowflake session
        session = get_snowflake_session()

        # Check and create role
        role_name = check_and_create_role(session)

        # Check and create warehouse
        warehouse_name = check_and_create_warehouse(session)

        # Check and create database
        database_name = check_and_create_database(session)

        # Check and create schemas
        schemas = check_and_create_schemas(session, database_name)

        # Check and create tables
        check_and_create_tables(session, database_name)

        # Grant usage privileges
        grant_usage_privileges(session, warehouse_name, database_name)

        # Verify setup
        tables_df = session.sql(f"""
            SELECT TABLE_NAME 
            FROM {database_name}.INFORMATION_SCHEMA.TABLES 
            WHERE TABLE_SCHEMA = 'ODS' 
            AND TABLE_NAME IN ('DEALERS', 'PRODUCTS', 'SALES', 'DP_MAPPING', 'EC_CLUB')
        """).to_pandas()
        tables_exist = tables_df['TABLE_NAME'].tolist()
        print(f"Tables in {database_name}.ODS: {tables_exist}")

        if len(tables_exist) == 5:
            print("All required tables verified successfully.")
        else:
            raise Exception(f"Expected 5 tables, but found {len(tables_exist)}: {tables_exist}")

        print(f"Snowflake environment setup completed in {time.time() - start_time:.2f} seconds")
    except Exception as e:
        print(f"Environment setup failed: {str(e)}")
        raise
    finally:
        session.close()
        print("Snowflake session closed.")

# %%
if __name__ == "__main__":
    main()
# Out:
# Starting Snowflake environment setup...
# Snowflake session established successfully.
# Error in check_and_create_role: (1304): 01bd535f-0305-ca7f-000a-ebe7000fb016: 000904 (42000): SQL compilation error: error line 2 at position 58
# invalid identifier 'DELETED'
# There are existing quoted column identifiers: []. Please use one of them to reference the column. See more details on Snowflake identifier requirements https://docs.snowflake.com/en/sql-reference/identifiers-syntax
# Environment setup failed: (1304): 01bd535f-0305-ca7f-000a-ebe7000fb016: 000904 (42000): SQL compilation error: error line 2 at position 58
# invalid identifier 'DELETED'
# There are existing quoted column identifiers: []. Please use one of them to reference the column. See more details on Snowflake identifier requirements https://docs.snowflake.com/en/sql-reference/identifiers-syntax
# Snowflake session closed.
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[21], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[20], line 11, in main()
#       8 session = get_snowflake_session()
#      10 # Check and create role
# ---> 11 role_name = check_and_create_role(session)
#      13 # Check and create warehouse
#      14 warehouse_name = check_and_create_warehouse(session)
#
# Cell In[14], line 10, in check_and_create_role(session)
#       4 role_name = "RECOMMENDATION_SYSTEM_ROLE"
#       5 try:
#       6     # Check if role exists
#       7     roles_df = session.sql(f"""
#       8         SELECT NAME FROM SNOWFLAKE.ACCOUNT_USAGE.ROLES
#       9         WHERE NAME = '{role_name}' AND DELETED IS NULL
# ---> 10     """).to_pandas()
#      11     if not roles_df.empty:
#      12         print(f"Role {role_name} already exists.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/telemetry.py:288, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     286 try:
#     287     with ResourceUsageCollector() as resource_usage_collector:
# --> 288         result = func(*args, **kwargs)
#     289     resource_usage = resource_usage_collector.get_resource_usage()
#     290 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/utils.py:1080, in publicapi.<locals>.call_wrapper(*args, **kwargs)
#    1076 kwargs["_emit_ast"] = is_ast_enabled()
#    1078 # TODO: Could modify internal docstring to display that users should not modify the _emit_ast parameter.
# -> 1080 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:1037, in DataFrame.to_pandas(self, statement_params, block, _emit_ast, **kwargs)
#    1034     _, kwargs[DATAFRAME_AST_PARAMETER] = self._session._ast_batch.flush(stmt)
#    1036 with open_telemetry_context_manager(self.to_pandas, self):
# -> 1037     result = self._session._conn.execute(
#    1038         self._plan,
#    1039         to_pandas=True,
#    1040         block=block,
#    1041         data_type=_AsyncResultType.PANDAS,
#    1042         _statement_params=create_or_update_statement_params_with_query_tag(
#    1043             statement_params or self._statement_params,
#    1044             self._session.query_tag,
#    1045             SKIP_LEVELS_TWO,
#    1046             collect_stacktrace=self._session.conf.get(
#    1047                 "collect_stacktrace_in_query_tag"
#    1048             ),
#    1049         ),
#    1050         **kwargs,
#    1051     )
#    1053 # if the returned result is not a pandas dataframe, raise Exception
#    1054 # this might happen when calling this method with non-select commands
#    1055 # e.g., session.sql("create ...").to_pandas()
#    1056 if block:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:624, in ServerConnection.execute(self, plan, to_pandas, to_iter, to_arrow, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     614 if (
#     615     is_in_stored_procedure()
#     616     and not block
#    (...)
#     619     )
#     620 ):  # pragma: no cover
#     621     raise NotImplementedError(
#     622         "Async query is not supported in stored procedure yet"
#     623     )
# --> 624 result_set, result_meta = self.get_result_set(
#     625     plan,
#     626     to_pandas,
#     627     to_iter,
#     628     **kwargs,
#     629     block=block,
#     630     data_type=data_type,
#     631     log_on_exception=log_on_exception,
#     632     case_sensitive=case_sensitive,
#     633     to_arrow=to_arrow,
#     634 )
#     635 if not block:
#     636     return result_set
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:233, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     230 for node in plan_nodes:
#     231     if isinstance(node, Selectable):
#     232         quoted_identifiers.extend(
# --> 233             node.snowflake_plan.quoted_identifiers
#     234         )
#     235     else:
#     236         quoted_identifiers.extend(
#     237             node.quoted_identifiers
#     238         )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:478, in SnowflakePlan.quoted_identifiers(self)
#     476     return self._metadata.quoted_identifiers
#     477 else:
# --> 478     return [attr.name for attr in self.attributes]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:487, in SnowflakePlan.attributes(self)
#     483     return self._metadata.attributes
#     484 assert (
#     485     self.schema_query is not None
#     486 ), "No schema query is available for the SnowflakePlan"
# --> 487 attributes = analyze_attributes(self.schema_query, self.session)
#     488 self._metadata = PlanMetadata(attributes=attributes, quoted_identifiers=None)
#     489 # We need to cache attributes on SelectStatement too because df._plan is not
#     490 # carried over to next SelectStatement (e.g., check the implementation of df.filter()).
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/schema_utils.py:98, in analyze_attributes(sql, session)
#      96 stack_trace = [frame.line for frame in stack] if len(stack) > 0 else None
#      97 start_time = time.time()
# ---> 98 attributes = session._get_result_attributes(sql)
#      99 e2e_time = time.time() - start_time
#     100 session._conn._telemetry_client.send_describe_query_details(
#     101     session._session_id, sql, e2e_time, stack_trace
#     102 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/session.py:2845, in Session._get_result_attributes(self, query)
#    2844 def _get_result_attributes(self, query: str) -> List[Attribute]:
# -> 2845     return self._conn.get_result_attributes(query)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:279, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     275         e.msg = f"{e.msg}\n{msg}"
#     276         ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     277             e
#     278         )
# --> 279         raise ne.with_traceback(tb) from None
#     280 elif e.sqlstate == "42601" and "SELECT with no columns" in e.msg:
#     281     # This is a special case when the select statement has no columns,
#     282     # and it's a reading XML query.
#     284     def search_read_file_node(
#     285         node: Union[SnowflakePlan, Selectable]
#     286     ) -> Optional[ReadFileNode]:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:151, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     149 def wrap(*args, **kwargs):
#     150     try:
# --> 151         return func(*args, **kwargs)
#     152     except snowflake.connector.errors.ProgrammingError as e:
#     153         from snowflake.snowpark._internal.analyzer.select_statement import (
#     154             Selectable,
#     155         )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:272, in ServerConnection.get_result_attributes(self, query)
#     269 @SnowflakePlan.Decorator.wrap_exception
#     270 def get_result_attributes(self, query: str) -> List[Attribute]:
#     271     return convert_result_meta_to_attribute(
# --> 272         self._run_new_describe(self._cursor, query), self.max_string_size
#     273     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:278, in ServerConnection._run_new_describe(self, cursor, query, **kwargs)
#     275 def _run_new_describe(
#     276     self, cursor: SnowflakeCursor, query: str, **kwargs: dict
#     277 ) -> Union[List[ResultMetadata], List["ResultMetadataV2"]]:
# --> 278     result_metadata = run_new_describe(cursor, query)
#     280     with self._lock:
#     281         for listener in filter(
#     282             lambda listener: hasattr(listener, "include_describe")
#     283             and listener.include_describe,
#     284             self._query_listeners,
#     285         ):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/schema_utils.py:158, in run_new_describe(cursor, query)
#     153 # ResultMetadataV2 may not currently be a type, depending on the connector
#     154 # version, so the argument types are pyright ignored
#     156 if hasattr(cursor, "_describe_internal"):
#     157     # Pyright does not perform narrowing here
# --> 158     return cursor._describe_internal(query)  # pyright: ignore
#     159 else:
#     160     return cursor.describe(query)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/connector/cursor.py:1174, in SnowflakeCursor._describe_internal(self, *args, **kwargs)
#    1163 """Obtain the schema of the result without executing the query.
#    1164
#    1165 This function takes the same arguments as execute, please refer to that function
#    (...)
#    1171     The schema of the result, in the new result metadata format.
#    1172 """
#    1173 kwargs["_describe_only"] = kwargs["_is_internal"] = True
# -> 1174 self.execute(*args, **kwargs)
#    1175 return self._description
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/connector/cursor.py:1134, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1130     is_integrity_error = (
#    1131         code == "100072"
#    1132     )  # NULL result in a non-nullable column
#    1133     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1134     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1135 return self
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/connector/errors.py:279, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     256 @staticmethod
#     257 def errorhandler_wrapper(
#     258     connection: SnowflakeConnection | None,
#    (...)
#     261     error_value: dict[str, Any],
#     262 ) -> None:
#     263     """Error handler wrapper that calls the errorhandler method.
#     264
#     265     Args:
#    (...)
#     276         exception to the first handler in that order.
#     277     """
# --> 279     handed_over = Error.hand_to_other_handler(
#     280         connection,
#     281         cursor,
#     282         error_class,
#     283         error_value,
#     284     )
#     285     if not handed_over:
#     286         raise Error.errorhandler_make_exception(
#     287             error_class,
#     288             error_value,
#     289         )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/connector/errors.py:334, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     332 if cursor is not None:
#     333     cursor.messages.append((error_class, error_value))
# --> 334     cursor.errorhandler(connection, cursor, error_class, error_value)
#     335     return True
#     336 elif connection is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/snowflake/connector/errors.py:210, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     208 errno = error_value.get("errno")
#     209 done_format_msg = error_value.get("done_format_msg")
# --> 210 raise error_class(
#     211     msg=error_value.get("msg"),
#     212     errno=None if errno is None else int(errno),
#     213     sqlstate=error_value.get("sqlstate"),
#     214     sfqid=error_value.get("sfqid"),
#     215     query=error_value.get("query"),
#     216     done_format_msg=(
#     217         None if done_format_msg is None else bool(done_format_msg)
#     218     ),
#     219     connection=connection,
#     220     cursor=cursor,
#     221 )
#
# SnowparkSQLException: (1304): 01bd535f-0305-ca7f-000a-ebe7000fb016: 000904 (42000): SQL compilation error: error line 2 at position 58
# invalid identifier 'DELETED'
# There are existing quoted column identifiers: []. Please use one of them to reference the column. See more details on Snowflake identifier requirements https://docs.snowflake.com/en/sql-reference/identifiers-syntax
